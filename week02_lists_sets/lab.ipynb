# %% [markdown]
# # IST1012 – Computer Programming II
# ## Week 2 Lab – Python Data Types, Lists, and Sets
#
# Follow the instructions in each cell.
#
# Write your code where requested.
#
# Do not skip tasks.

# %% [markdown]
# ## Task 1 – Variables and Data Types
#
# Create variables that store the following information:
#
# - A student's name
# - A student's age
# - A student's height
# - Whether the student is enrolled in this course
#
# Then print all variables.
#
# Observe the output.

# %%
student_name = "CEM"
student_age = 24
student_height = 185

print(student_name)
print(student_age)
print(student_height)

# %% [markdown]
# ## Task 2 – Input and Type Conversion
#
# Write a program that asks the user to enter:
#
# - Their name
# - Their age
# - Their favorite programming language
#
# After collecting the information, print:
#
# - The name
# - The age next year
# - The favorite programming language

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
favorite_language = input("Enter your favorite programming language: ")


age_next_year = age + 1

print("Name:", name)
print("favorite language", favorite_language)
print("Age next year:", age_next_year)
# Out:
# Enter your name: cem
# Enter your age: 24
# Enter your favorite programming language: python
# Name: cem
# favorite language python
# Age next year: 25

# %% [markdown]
# ## Task 3 – Working with Lists
#
# Create a list containing the following numbers:
#
# 22
# 80
# 443
# 21
# 25
#
# Then perform the following operations:
#
# - Print the first element of the list
# - Print the last element of the list
# - Print the total number of elements in the list

# %%
number = [22, 80, 443, 21, 25]

print(number[0])
print(number[-1])
print(len(number))

# %% [markdown]
# ## Task 4 – Modifying Lists
#
# Create a list of three programming languages.
#
# Then:
#
# - Add one new language to the list
# - Print the updated list
# - Print how many elements the list contains

# %%
languages = ["Python", "Java", "C++"]

languages.append("JavaScript")

print(languages)

# %% [markdown]
# ## Task 5 – Introduction to Sets
#
# Create a list containing the following IP addresses:
#
# 192.168.1.1
# 192.168.1.2
# 192.168.1.1
# 10.0.0.5
# 10.0.0.5
#
# Convert this list into a **set**.
#
# Print the set.

# %%
ip_adresses = ["192.168.1.1", "192.168.1.2", "192.168.1.1", "10.0.0.5", "10.0.0.5"]

ip_set = set(ip_adresses)

print(ip_set)
# Out:
# {'192.168.1.2', '10.0.0.5', '192.168.1.1'}

# %% [markdown]
# ## Task 6 – Unique Values
#
# Using the set created in the previous task:
#
# - Print each IP address on a separate line
# - Print how many unique IP addresses exist

# %%
for ip_address in ip_set:
    print(ip_address)

# %% [markdown]
# ## Task 7 – User Input with Lists
#
# Ask the user to enter **five IP addresses**.
#
# Store them in a list.
#
# Then:
#
# - Convert the list into a set
# - Print the unique IP addresses
# - Print the total number of unique IP addresses

# %%
ip_addresses = []

for i in range(5):
    number = input("Enter an IP address: ")
    ip_addresses.append(number)

ip_set = set(ip_addresses)

print(ip_set)
print(len(ip_set))
# Out:
# Enter an IP address: 21312
# Enter an IP address: 324234
# Enter an IP address: 13123
# Enter an IP address: 432423
# Enter an IP address: 12312
# {'13123', '12312', '432423', '324234', '21312'}
# 5
